# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
ceps = pd.read_csv('./Datas/standart_estado', dtype=str)

# %%
ceps
# Out:
#         Coluna
# 0     00000000
# 1     00005820
# 2     01031970
# 3     01033001
# 4     01041000
# 5     01046925
# 6     01047020
# 7     01050020
# 8     01050030
# 9     01105010
# 10    01121000
# 11    01122030
# 12    01124010
# 13    01131000
# 14    01131010
# 15    01132010
# 16    01132010
# 17    01136010
# 18    01141000
# 19    01153000
# 20    01155040
# 21    01207001
# 22    01214100
# 23    01215010
# 24    01215010
# 25    01217000
# 26    01217011
# 27    01220010
# 28    01222000
# 29    01222001
# 30    01222010
# 31    01223001
# 32    01223010
# 33    01224000
# 34    01224010
# 35    01224030
# 36    01224040
# 37    01224050
# 38    01226000
# 39    01226001
# 40    01226010
# 41    01226020
# 42    01227200
# 43    01228100
# 44    01229010
# 45    01230001
# 46    01230020
# 47    01231001
# 48    01231010
# 49    01231020
# 50    01232001
# 51    01232010
# 52    01232010
# 53    01232020
# 54    01233010
# 55    01233020
# 56    01233060
# ...

# %%
lista_cep = ceps['Coluna'].explode().tolist()

# %%
lista_cep
# Out:
# ['00000000',
#  '00005820',
#  '01031970',
#  '01033001',
#  '01041000',
#  '01046925',
#  '01047020',
#  '01050020',
#  '01050030',
#  '01105010',
#  '01121000',
#  '01122030',
#  '01124010',
#  '01131000',
#  '01131010',
#  '01132010',
#  '01132010',
#  '01136010',
#  '01141000',
#  '01153000',
#  '01155040',
#  '01207001',
#  '01214100',
#  '01215010',
#  '01215010',
#  '01217000',
#  '01217011',
#  '01220010',
#  '01222000',
#  '01222001',
#  '01222010',
#  '01223001',
#  '01223010',
#  '01224000',
#  '01224010',
#  '01224030',
#  '01224040',
#  '01224050',
#  '01226000',
#  '01226001',
#  '01226010',
#  '01226020',
#  '01227200',
#  '01228100',
#  '01229010',
#  '01230001',
#  '01230020',
#  '01231001',
#  '01231010',
#  '01231020',
#  '01232001',
#  '01232010',
#  '01232010',
#  '01232020',
#  '01233010',
#  '01233020',
#  '01233060',
#  '01234001',
#  '01239000',
#  '01239020',
#  '01239040',
#  '01240010',
#  '01240906',
#  '01241001',
#  '01241001',
#  '01241020',
# ...

# %%
len(lista_cep)
# Out:
# 3672

# %%
faixa_estados = {
    'SP': ('01000000', '19999999'),
    'RJ': ('20000000', '28999999'),
    'BA': ('40000000', '48999999'),
    'CE': ('60000000', '63999999'),
    'PR': ('80000000', '87999999'),
    'AC': ('69900000', '69999999'),
    'AL': ('57000000', '57999999'),
    'AM1': ('69000000', '69299999'),
    'AM2': ('69400000', '69899999'),
    'AP': ('68900000', '68999999'), 
    'MG': ('30000000', '39999999'),
    'RS': ('90000000', '99999999'),
    'SC': ('88000000', '89999999'),
    'MT': ('78000000', '78899999'),
    'TO': ('77000000', '77999999'),
    'RR': ('69300000', '69399999'),
    'PA': ('66000000', '68899999'),
    'ES': ('29000000', '29999999'),
    'SE': ('49000000', '49999999'),
    'PE': ('50000000', '56999999'),
    'PB': ('58000000', '58999999'),
    'RN': ('59000000', '59999999'),
    'PI': ('64000000', '64999999'),
    'MA': ('65000000', '65999999'),
    'GO - Goias 1': ('72800000', '72999999'),
    'GO - Goias 2': ('73700000', '76799999'),
    'RO': ('76800000', '76999999'),
    'MS': ('79000000', '79999999')
}

# %%
def identifca_estado(cep):
    for estado, (inicio, fim) in faixa_estados.items():
        if inicio <= cep <= fim:
            return estado
    return 'Estado não encontrado'

# %%
ceps_df = pd.DataFrame({'CEP': lista_cep})
ceps_df['Estado'] = ceps_df['CEP'].apply(identifca_estado)

# %%
ceps_df
# Out:
#            CEP                 Estado
# 0     00000000  Estado não encontrado
# 1     00005820  Estado não encontrado
# 2     01031970                     SP
# 3     01033001                     SP
# 4     01041000                     SP
# 5     01046925                     SP
# 6     01047020                     SP
# 7     01050020                     SP
# 8     01050030                     SP
# 9     01105010                     SP
# 10    01121000                     SP
# 11    01122030                     SP
# 12    01124010                     SP
# 13    01131000                     SP
# 14    01131010                     SP
# 15    01132010                     SP
# 16    01132010                     SP
# 17    01136010                     SP
# 18    01141000                     SP
# 19    01153000                     SP
# 20    01155040                     SP
# 21    01207001                     SP
# 22    01214100                     SP
# 23    01215010                     SP
# ...

# %%
type(ceps_df)
# Out:
# pandas.core.frame.DataFrame

# %%
ceps_df.to_excel('./Datas/StandartEstado.xlsx', index = False)

# %%
ceps_df
# Out:
#            CEP                 Estado
# 0     00000000  Estado não encontrado
# 1     00005820  Estado não encontrado
# 2     01031970                     SP
# 3     01033001                     SP
# 4     01041000                     SP
# 5     01046925                     SP
# 6     01047020                     SP
# 7     01050020                     SP
# 8     01050030                     SP
# 9     01105010                     SP
# 10    01121000                     SP
# 11    01122030                     SP
# 12    01124010                     SP
# 13    01131000                     SP
# 14    01131010                     SP
# 15    01132010                     SP
# 16    01132010                     SP
# 17    01136010                     SP
# 18    01141000                     SP
# 19    01153000                     SP
# 20    01155040                     SP
# 21    01207001                     SP
# 22    01214100                     SP
# 23    01215010                     SP
# ...

# %% [markdown]
# # Agrupar por Estado

# %%
cep_por_estado = ceps_df.groupby('Estado')['CEP'].count()

# %%
cep_por_estado
# Out:
# Estado
# AC                          4
# AL                          5
# AM1                         1
# AM2                         2
# BA                         54
# CE                         30
# ES                         33
# Estado não encontrado       3
# GO - Goias 1                4
# GO - Goias 2               44
# MA                         11
# MG                        171
# MS                         23
# MT                         61
# PA                         35
# PB                         16
# PE                         13
# PI                         16
# PR                        108
# RJ                         41
# RN                         12
# RO                         20
# RR                          9
# RS                        117
# SC                         96
# SE                          6
# SP                       2713
# TO                         24
# Name: CEP, dtype: int64

# %%
group_estado = cep_por_estado.to_frame()

# %%
group_estado
# Out:
#                         CEP
# Estado
# AC                        4
# AL                        5
# AM1                       1
# AM2                       2
# BA                       54
# CE                       30
# ES                       33
# Estado não encontrado     3
# GO - Goias 1              4
# GO - Goias 2             44
# MA                       11
# MG                      171
# MS                       23
# MT                       61
# PA                       35
# PB                       16
# PE                       13
# PI                       16
# PR                      108
# RJ                       41
# RN                       12
# RO                       20
# RR                        9
# RS                      117
# SC                       96
# SE                        6
# SP                     2713
# TO                       24

# %%
group_estado.to_excel('./Datas/estado_agrupado_standart.xlsx', index= True)
